# %% [markdown]
# ---
# ## 1. Setup and Data Loading

# %%
# ============================================
# IMPORT LIBRARIES
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

print("✅ Libraries imported")
# Out:
# ✅ Libraries imported

# %%
# ============================================
# LOAD RAW DATA
# ============================================

df = pd.read_csv('../data/raw/Output_10yrs_reported_schools_17220.csv')

# Standardize column names
df = df.rename(columns={
    'Survey Year': 'Year',
    'Institution Name': 'Institution_Name',
    'State CD': 'State',
    'Classification Name': 'Classification'
})

# CRITICAL: Sort by institution and year for correct lag calculations
df = df.sort_values(['UNITID', 'Year']).reset_index(drop=True)

print(f"✅ Loaded raw data: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"📅 Years: {df['Year'].min()} - {df['Year'].max()}")
print(f"🏫 Institutions: {df['UNITID'].nunique():,}")
# Out:
# ✅ Loaded raw data: 17,220 rows × 580 columns
# 📅 Years: 2014 - 2023
# 🏫 Institutions: 1,722

# %% [markdown]
# ---
# ## 2. Year Allocation Reminder
#
# Before we start, let's be clear about how years will be used:

# %%
# ============================================
# YEAR ALLOCATION DOCUMENTATION
# ============================================

year_info = """
╔══════════════════════════════════════════════════════════════════════════════╗
║                              YEAR ALLOCATION                                 ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║  Raw Data: 2014-2023 (10 years, 17,220 records)                              ║
║                                                                              ║
║  After Feature Engineering:                                                  ║
║  ─────────────────────────────                                               ║
║  • 2014-2016: CONSUMED for 2-year lag calculations                           ║
║               (not in final dataset, used as lookback)                       ║
║                                                                              ║
║  • 2017-2022: USABLE ROWS (have both features AND targets)                   ║
║               These will be split into train/val/test                        ║
║                                                                              ║
║  • 2023:      FUTURE PREDICTION (has features, NO target)                    ║
║               Target requires 2024 data which doesn't exist                  ║
║                                                                              ║
║  Expected Row Counts:                                                        ║
║  ─────────────────────                                                       ║
║  • 2017-2022 with targets: ~1,722 × 6 = ~10,332 rows                         ║
║  • 2023 without targets: ~1,722 rows                                         ║
║                                                                              ║
╚══════════════════════════════════════════════════════════════════════════════╝
"""

print(year_info)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║                              YEAR ALLOCATION                                 ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║  Raw Data: 2014-2023 (10 years, 17,220 records)                              ║
# ║                                                                              ║
# ║  After Feature Engineering:                                                  ║
# ║  ─────────────────────────────                                               ║
# ║  • 2014-2016: CONSUMED for 2-year lag calculations                           ║
# ║               (not in final dataset, used as lookback)                       ║
# ║                                                                              ║
# ║  • 2017-2022: USABLE ROWS (have both features AND targets)                   ║
# ║               These will be split into train/val/test                        ║
# ║                                                                              ║
# ║  • 2023:      FUTURE PREDICTION (has features, NO target)                    ║
# ║               Target requires 2024 data which doesn't exist                  ║
# ║                                                                              ║
# ║  Expected Row Counts:                                                        ║
# ║  ─────────────────────                                                       ║
# ║  • 2017-2022 with targets: ~1,722 × 6 = ~10,332 rows                         ║
# ║  • 2023 without targets: ~1,722 rows                                         ║
# ║                                                                              ║
# ╚══════════════════════════════════════════════════════════════════════════════╝

# %% [markdown]
# ---
# ## 3. Build Structural Features
#
# These features don't involve time calculations.

# %%
# ============================================
# FEATURE: Division
# ============================================
# Based on: EDA Observation 2 - Huge differences between D1, D2, D3
# Why useful: D1 has 10x revenue of D2; fundamentally different profiles
# Why safe: Structural attribute, doesn't change, no future info

def extract_division(classification):
    """Extract D1/D2/D3 from full classification name"""
    if pd.isna(classification):
        return 'Unknown'
    if 'NCAA Division I' in classification:
        return 'D1'
    elif 'NCAA Division II' in classification:
        return 'D2'
    elif 'NCAA Division III' in classification:
        return 'D3'
    else:
        return 'Other'

df['Division'] = df['Classification'].apply(extract_division)

print("✅ Division feature created")
print(df['Division'].value_counts())
# Out:
# ✅ Division feature created
# Division
# D1         9888
# Other      7176
# Unknown     156
# Name: count, dtype: int64

# %%
# ============================================
# FEATURE: State (already exists as 'State')
# ============================================
# Based on: General - Regional patterns may exist
# Why useful: State funding policies vary
# Why safe: Location doesn't change, no future info

print("✅ State feature available")
print(f"Unique states: {df['State'].nunique()}")
# Out:
# ✅ State feature available
# Unique states: 51

# %% [markdown]
# ---
# ## 4. Build Current Year Metrics

# %%
# ============================================
# FEATURE: Total_Athletes
# ============================================
# Based on: EDA Observation 5 - Participation correlates with financials
# Formula: Men's + Women's participation
# Why useful: Program size indicator
# Why safe: Current year value only

df['Total_Athletes'] = (
    df["Unduplicated Count Men's Participation"].fillna(0) + 
    df["Unduplicated Count Women's Participation"].fillna(0)
)

print("✅ Total_Athletes feature created")
print(f"   Mean: {df['Total_Athletes'].mean():.0f}")
print(f"   Max:  {df['Total_Athletes'].max():.0f}")
# Out:
# ✅ Total_Athletes feature created
#    Mean: 307
#    Max:  1416

# %%
# ============================================
# FEATURE: Efficiency_Ratio
# ============================================
# Based on: EDA Observation 4 - Rev/Exp ratio captures financial health
# Formula: Revenue[t] / Expenses[t]
# Why useful: >1 = surplus, <1 = deficit
# Why safe: Uses only current year data

df['Efficiency_Ratio'] = df['Grand Total Revenue'] / df['Grand Total Expenses'].replace(0, np.nan)

print("✅ Efficiency_Ratio feature created")
print(f"   Mean:   {df['Efficiency_Ratio'].mean():.3f}")
print(f"   Median: {df['Efficiency_Ratio'].median():.3f}")
# Out:
# ✅ Efficiency_Ratio feature created
#    Mean:   1.027
#    Median: 1.000

# %%
# ============================================
# FEATURE: Revenue_Per_Athlete
# ============================================
# Based on: EDA Observation 5 - Normalized metrics are useful
# Formula: Revenue[t] / Total_Athletes[t]
# Why useful: Comparable across institutions of different sizes
# Why safe: Uses only current year data

df['Revenue_Per_Athlete'] = df['Grand Total Revenue'] / df['Total_Athletes'].replace(0, np.nan)

print("✅ Revenue_Per_Athlete feature created")
print(f"   Mean:   ${df['Revenue_Per_Athlete'].mean():,.0f}")
print(f"   Median: ${df['Revenue_Per_Athlete'].median():,.0f}")
# Out:
# ✅ Revenue_Per_Athlete feature created
#    Mean:   $27,910
#    Median: $12,575

# %%
# ============================================
# FEATURE: Reports_Exactly_One
# ============================================
# Based on: EDA Observation 6 - Many report exactly 1.0 efficiency
# Formula: 1 if Efficiency_Ratio == 1.0 else 0
# Why useful: Flags potential accounting anomaly
# Why safe: Uses only current year data

df['Reports_Exactly_One'] = (df['Efficiency_Ratio'] == 1.0).astype(int)

print("✅ Reports_Exactly_One flag created")
print(f"   Institutions reporting exactly 1.0: {df['Reports_Exactly_One'].sum():,} ({df['Reports_Exactly_One'].mean()*100:.1f}%)")
# Out:
# ✅ Reports_Exactly_One flag created
#    Institutions reporting exactly 1.0: 10,315 (59.9%)

# %% [markdown]
# ---
# ## 5. Build Growth Features (1-Year Lookback)
#
# These features use data from the PREVIOUS year (safe).

# %%
# ============================================
# GROUP BY INSTITUTION FOR LAG CALCULATIONS
# ============================================
# We group by UNITID so that lag calculations are within each institution
# shift(1) means: look at the PREVIOUS year's value (SAFE)
# shift(-1) would mean: look at NEXT year (FORBIDDEN for features)

grouped = df.groupby('UNITID')

print("✅ Grouped by institution for lag calculations")
# Out:
# ✅ Grouped by institution for lag calculations

# %%
# ============================================
# FEATURE: Revenue_Growth_1yr
# ============================================
# Based on: EDA Observations 1 & 3 - Growth rates normalize across scales
# Formula: (Revenue[t] - Revenue[t-1]) / Revenue[t-1]
# Why useful: Captures recent momentum
# Why safe: Uses t and t-1 only (PAST data)

# Get previous year's revenue using shift(1) - this is SAFE
df['Revenue_Prev'] = grouped['Grand Total Revenue'].shift(1)
df['Revenue_Growth_1yr'] = (df['Grand Total Revenue'] - df['Revenue_Prev']) / df['Revenue_Prev']

# Clean up temporary column
df = df.drop(columns=['Revenue_Prev'])

print("✅ Revenue_Growth_1yr feature created")
print(f"   Mean:   {df['Revenue_Growth_1yr'].mean()*100:.2f}%")
print(f"   Median: {df['Revenue_Growth_1yr'].median()*100:.2f}%")
# Out:
# ✅ Revenue_Growth_1yr feature created
#    Mean:   8.12%
#    Median: 4.80%

# %%
# ============================================
# FEATURE: Expense_Growth_1yr
# ============================================
# Based on: EDA Observation 3 - Expense growth patterns matter
# Formula: (Expenses[t] - Expenses[t-1]) / Expenses[t-1]
# Why useful: High expense growth could signal trouble
# Why safe: Uses t and t-1 only (PAST data)

df['Expense_Prev'] = grouped['Grand Total Expenses'].shift(1)
df['Expense_Growth_1yr'] = (df['Grand Total Expenses'] - df['Expense_Prev']) / df['Expense_Prev']

df = df.drop(columns=['Expense_Prev'])

print("✅ Expense_Growth_1yr feature created")
print(f"   Mean:   {df['Expense_Growth_1yr'].mean()*100:.2f}%")
print(f"   Median: {df['Expense_Growth_1yr'].median()*100:.2f}%")
# Out:
# ✅ Expense_Growth_1yr feature created
#    Mean:   7.99%
#    Median: 4.89%

# %% [markdown]
# ---
# ## 6. Build Trend Features (2-Year Lookback)
#
# These features use data from the past 2 years (safe).

# %%
# ============================================
# FEATURE: Revenue_CAGR_2yr
# ============================================
# Based on: EDA Observation 3 - Multi-year trends more stable
# Formula: (Revenue[t] / Revenue[t-2])^0.5 - 1
# Why useful: Compound annual growth rate; smoother than 1-year
# Why safe: Uses t and t-2 only (PAST data)

df['Revenue_2yr_ago'] = grouped['Grand Total Revenue'].shift(2)
df['Revenue_CAGR_2yr'] = (df['Grand Total Revenue'] / df['Revenue_2yr_ago']) ** 0.5 - 1

df = df.drop(columns=['Revenue_2yr_ago'])

print("✅ Revenue_CAGR_2yr feature created")
print(f"   Mean:   {df['Revenue_CAGR_2yr'].mean()*100:.2f}%")
print(f"   Median: {df['Revenue_CAGR_2yr'].median()*100:.2f}%")
# Out:
# ✅ Revenue_CAGR_2yr feature created
#    Mean:   6.35%
#    Median: 4.80%

# %%
# ============================================
# FEATURE: Expense_CAGR_2yr
# ============================================
# Based on: EDA Observation 3 - Expense trajectory matters
# Formula: (Expenses[t] / Expenses[t-2])^0.5 - 1
# Why useful: Compound expense growth signals spending trajectory
# Why safe: Uses t and t-2 only (PAST data)

df['Expense_2yr_ago'] = grouped['Grand Total Expenses'].shift(2)
df['Expense_CAGR_2yr'] = (df['Grand Total Expenses'] / df['Expense_2yr_ago']) ** 0.5 - 1

df = df.drop(columns=['Expense_2yr_ago'])

print("✅ Expense_CAGR_2yr feature created")
print(f"   Mean:   {df['Expense_CAGR_2yr'].mean()*100:.2f}%")
print(f"   Median: {df['Expense_CAGR_2yr'].median()*100:.2f}%")
# Out:
# ✅ Expense_CAGR_2yr feature created
#    Mean:   6.27%
#    Median: 4.82%

# %%
# ============================================
# FEATURE: Efficiency_Mean_2yr
# ============================================
# Based on: EDA Observation 4 - Efficiency over time
# Formula: mean(Efficiency[t], Efficiency[t-1])
# Why useful: Smoothed efficiency reduces noise
# Why safe: Uses t and t-1 only (PAST data)

df['Efficiency_Mean_2yr'] = grouped['Efficiency_Ratio'].transform(
    lambda x: x.rolling(window=2, min_periods=2).mean()
)

print("✅ Efficiency_Mean_2yr feature created")
print(f"   Mean:   {df['Efficiency_Mean_2yr'].mean():.3f}")
print(f"   Median: {df['Efficiency_Mean_2yr'].median():.3f}")
# Out:
# ✅ Efficiency_Mean_2yr feature created
#    Mean:   1.028
#    Median: 1.000

# %% [markdown]
# ---
# ## 7. Build Volatility Features

# %%
# ============================================
# FEATURE: Revenue_Volatility_2yr
# ============================================
# Based on: EDA Observation 7 - Volatility varies by institution
# Formula: std(Revenue[t], Revenue[t-1])
# Why useful: High volatility = unstable finances
# Why safe: Uses t and t-1 only (PAST data)

df['Revenue_Volatility_2yr'] = grouped['Grand Total Revenue'].transform(
    lambda x: x.rolling(window=2, min_periods=2).std()
)

print("✅ Revenue_Volatility_2yr feature created")
# Out:
# ✅ Revenue_Volatility_2yr feature created

# %%
# ============================================
# FEATURE: Expense_Volatility_2yr
# ============================================
# Based on: EDA Observation 7 - Volatility captures stability
# Formula: std(Expenses[t], Expenses[t-1])
# Why useful: Expense volatility signals unpredictable spending
# Why safe: Uses t and t-1 only (PAST data)

df['Expense_Volatility_2yr'] = grouped['Grand Total Expenses'].transform(
    lambda x: x.rolling(window=2, min_periods=2).std()
)

print("✅ Expense_Volatility_2yr feature created")
# Out:
# ✅ Expense_Volatility_2yr feature created

# %% [markdown]
# ---
# ## 8. Create Target Variable
#
# **Note:** The target uses `shift(-1)` because we're looking at what happens NEXT year. This is correct for targets, but would be forbidden for features.

# %%
# ============================================
# TARGET: Financial_Trajectory
# ============================================
# Definition: Predict trajectory from year t to year t+1
# 
# IMPORTANT: We use shift(-1) here because the TARGET should look at
# future outcomes. This is the ONE place where looking ahead is valid.
#
# Classes:
# - Improving (2): Rev Growth > 3% AND Exp Growth < Rev Growth
# - Declining (0): Rev Growth < 0% OR Exp Growth > Rev Growth + 3%
# - Stable (1): Everything else

# Calculate FUTURE growth (what happens from t to t+1)
# shift(-1) means: look at NEXT year's value
df['Future_Revenue'] = grouped['Grand Total Revenue'].shift(-1)
df['Future_Expenses'] = grouped['Grand Total Expenses'].shift(-1)

df['Future_Revenue_Growth'] = (df['Future_Revenue'] - df['Grand Total Revenue']) / df['Grand Total Revenue']
df['Future_Expense_Growth'] = (df['Future_Expenses'] - df['Grand Total Expenses']) / df['Grand Total Expenses']

# Define trajectory classification function
def classify_trajectory(row):
    """Classify financial trajectory based on future growth."""
    rev_growth = row['Future_Revenue_Growth']
    exp_growth = row['Future_Expense_Growth']
    
    if pd.isna(rev_growth) or pd.isna(exp_growth):
        return np.nan
    
    # IMPROVING: Strong revenue growth AND expenses under control
    if (rev_growth > 0.03) and (exp_growth < rev_growth):
        return 'Improving'
    
    # DECLINING: Revenue shrinking OR expenses outpacing revenue
    elif (rev_growth < 0.00) or (exp_growth > rev_growth + 0.03):
        return 'Declining'
    
    # STABLE: Everything else
    else:
        return 'Stable'

df['Target_Trajectory'] = df.apply(classify_trajectory, axis=1)

# Numeric encoding
trajectory_map = {'Declining': 0, 'Stable': 1, 'Improving': 2}
df['Target_Label'] = df['Target_Trajectory'].map(trajectory_map)

# Clean up intermediate columns
df = df.drop(columns=['Future_Revenue', 'Future_Expenses', 'Future_Revenue_Growth', 'Future_Expense_Growth'])

print("✅ Target variable created")
print(df['Target_Trajectory'].value_counts())
# Out:
# ✅ Target variable created
# Target_Trajectory
# Stable       7513
# Declining    5809
# Improving    2176
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 9. Filter to Usable Rows
#
# We need to remove rows that:
# 1. Don't have enough history for 2-year features (2014-2016)
# 2. Don't have a target (2023)

# %%
# ============================================
# FILTER ROWS
# ============================================

print("📊 BEFORE FILTERING:")
print(f"   Total rows: {len(df):,}")
print(f"   Year range: {df['Year'].min()} - {df['Year'].max()}")

# Rows with valid 2-year features (need Revenue_CAGR_2yr to be non-null)
has_features = df['Revenue_CAGR_2yr'].notna()
print(f"   Rows with valid features: {has_features.sum():,}")

# Rows with valid target
has_target = df['Target_Label'].notna()
print(f"   Rows with valid target: {has_target.sum():,}")

# Rows usable for training (have BOTH features AND target)
usable_for_training = has_features & has_target
print(f"   Rows usable for training: {usable_for_training.sum():,}")

# Rows usable for prediction (have features but NO target - 2023)
usable_for_prediction = has_features & ~has_target
print(f"   Rows for future prediction: {usable_for_prediction.sum():,}")
# Out:
# 📊 BEFORE FILTERING:
#    Total rows: 17,220
#    Year range: 2014 - 2023
#    Rows with valid features: 13,776
#    Rows with valid target: 15,498
#    Rows usable for training: 12,054
#    Rows for future prediction: 1,722

# %%
# ============================================
# CREATE TRAINING AND PREDICTION DATASETS
# ============================================

# Training data: rows with both features and target (2017-2022)
df_train = df[usable_for_training].copy()

# Prediction data: rows with features but no target (2023)
df_predict = df[usable_for_prediction].copy()

print(f"\n✅ DATASETS CREATED:")
print(f"   Training dataset: {len(df_train):,} rows")
print(f"   Years in training: {df_train['Year'].min()} - {df_train['Year'].max()}")
print(f"   \n   Prediction dataset: {len(df_predict):,} rows")
print(f"   Years in prediction: {df_predict['Year'].unique()}")
# Out:
# ✅ DATASETS CREATED:
#    Training dataset: 12,054 rows
#    Years in training: 2016 - 2022
#
#    Prediction dataset: 1,722 rows
#    Years in prediction: [2023]

# %% [markdown]
# ---
# ## 10. ⚠️ CRITICAL: Leakage Verification
#
# Before saving, we MUST verify there's no data leakage.

# %%
# ============================================
# LEAKAGE CHECK 1: No Target-Derived Features
# ============================================

print("🔍 LEAKAGE CHECK 1: Checking for target-derived features...")
print("="*60)

# List all columns
all_columns = df_train.columns.tolist()

# Check for any column containing 'Target' except the actual target columns
target_related = [col for col in all_columns if 'Target' in col]
allowed_target_cols = ['Target_Trajectory', 'Target_Label']
forbidden_target_cols = [col for col in target_related if col not in allowed_target_cols]

if len(forbidden_target_cols) == 0:
    print("✅ PASS: No target-derived features found in dataset")
else:
    print("❌ FAIL: Found target-derived features:")
    for col in forbidden_target_cols:
        print(f"   - {col}")
    print("   These MUST be removed before training!")
# Out:
# 🔍 LEAKAGE CHECK 1: Checking for target-derived features...
# ============================================================
# ✅ PASS: No target-derived features found in dataset

# %%
# ============================================
# LEAKAGE CHECK 2: Verify Feature Columns
# ============================================

print("\n🔍 LEAKAGE CHECK 2: Listing all feature columns...")
print("="*60)

# Define expected feature columns
identifier_cols = ['UNITID', 'Institution_Name', 'Year', 'State', 'Classification']
target_cols = ['Target_Trajectory', 'Target_Label']

feature_cols = [col for col in all_columns if col not in identifier_cols + target_cols]

print("FEATURE COLUMNS (will be used for training):")
for i, col in enumerate(feature_cols, 1):
    print(f"   {i:2}. {col}")

print(f"\nTotal features: {len(feature_cols)}")
# Out:
# 🔍 LEAKAGE CHECK 2: Listing all feature columns...
# ============================================================
# FEATURE COLUMNS (will be used for training):
#     1. OPE ID
#     2. Classification Other
#     3. Sanction Code
#     4. Sanction Name
#     5. Male Undergraduates
#     6. Female Undergraduates
#     7. Total Undergraduates
#     8. Archery Men's Team Participation
#     9. Archery Women's Team Participation
#    10. Archery Coed Team Men Participation
#    11. Archery Coed Team Women Participation
#    12. Archery Total Participation
#    13. Badminton Women's Team Participation
#    14. Badminton Total Participation
#    15. Baseball Men's Team Participation
#    16. Baseball Total Participation
#    17. Basketball Men's Team Participation
#    18. Basketball Women's Team Participation
#    19. Basketball Coed Team Men Participation
#    20. Basketball Coed Team Women Participation
#    21. Basketball Total Participation
#    22. Beach Volleyball Men's Team Participation
#    23. Beach Volleyball Women's Team Participation
#    24. Beach Volleyball Total Participation
#    25. Bowling Men's Team Participation
#    26. Bowling Women's Team Participation
#    27. Bowling Coed Team Men Participation
#    28. Bowling Coed Team Women Participation
#    29. Bowling Total Participation
#    30. All Track Combined Men's Team Participation
#    31. All Track Combined Women's Team Participation
#    32. All Track Combined Coed Team Men Participation
#    33. All Track Combined Coed Team Women Participation
#    34. All Track Combined Total Participation
#    35. Diving Men's Team Participation
#    36. Diving Women's Team Participation
#    37. Diving Total Participation
#    38. Equestrian Men's Team Participation
#    39. Equestrian Women's Team Participation
#    40. Equestrian Coed Team Men Participation
#    41. Equestrian Coed Team Women Participation
#    42. Equestrian Total Participation
#    43. Fencing Men's Team Participation
#    44. Fencing Women's Team Participation
#    45. Fencing Coed Team Men Participation
#    46. Fencing Coed Team Women Participation
#    47. Fencing Total Participation
#    48. Field Hockey Women's Team Participation
#    49. Field Hockey Total Participation
#    50. Football Men's Team Participation
#    51. Football Total Participation
#    52. Golf Men's Team Participation
#    53. Golf Women's Team Participation
#    54. Golf Coed Team Men Participation
#    55. Golf Coed Team Women Participation
#    56. Golf Total Participation
#    57. Gymnastics Men's Team Participation
#    58. Gymnastics Women's Team Participation
#    59. Gymnastics Coed Team Men Participation
#    60. Gymnastics Coed Team Women Participation
#    61. Gymnastics Total Participation
#    62. Ice Hockey Men's Team Participation
#    63. Ice Hockey Women's Team Participation
#    64. Ice Hockey Total Participation
#    65. Lacrosse Men's Team Participation
#    66. Lacrosse Women's Team Participation
#    67. Lacrosse Total Participation
#    68. Rifle Men's Team Participation
#    69. Rifle Women's Team Participation
#    70. Rifle Coed Team Men Participation
#    71. Rifle Coed Team Women Participation
#    72. Rifle Total Participation
#    73. Rodeo Men's Team Participation
#    74. Rodeo Women's Team Participation
#    75. Rodeo Coed Team Men Participation
#    76. Rodeo Coed Team Women Participation
#    77. Rodeo Total Participation
#    78. Rowing Men's Team Participation
#    79. Rowing Women's Team Participation
#    80. Rowing Total Participation
#    81. Sailing Men's Team Participation
#    82. Sailing Women's Team Participation
#    83. Sailing Coed Team Men Participation
#    84. Sailing Coed Team Women Participation
#    85. Sailing Total Participation
#    86. Skiing Men's Team Participation
#    87. Skiing Women's Team Participation
#    88. Skiing Total Participation
#    89. Soccer Men's Team Participation
#    90. Soccer Women's Team Participation
#    91. Soccer Coed Team Men Participation
#    92. Soccer Coed Team Women Participation
#    93. Soccer Total Participation
#    94. Softball Women's Team Participation
#    95. Softball Total Participation
#    96. Squash Men's Team Participation
#    97. Squash Women's Team Participation
#    98. Squash Coed Team Men Participation
#    99. Squash Coed Team Women Participation
#    100. Squash Total Participation
#    101. Swimming and Diving Men's Team Participation
#    102. Swimming and Diving Women's Team Participation
#    103. Swimming and Diving Total Participation
#    104. Swimming Men's Team Participation
#    105. Swimming Women's Team Participation
#    106. Swimming Total Participation
#    107. Synchronized Swimming Women's Team Participation
#    108. Synchronized Swimming Total Participation
#    109. Table Tennis Men's Team Participation
#    110. Table Tennis Women's Team Participation
#    111. Table Tennis Total Participation
#    112. Tennis Men's Team Participation
#    113. Tennis Women's Team Participation
#    114. Tennis Coed Team Men Participation
#    115. Tennis Coed Team Women Participation
#    116. Tennis Total Participation
#    117. Track and Field Indoor Men's Team Participation
#    118. Track and Field Indoor Women's Team Participation
#    119. Track and Field Indoor Total Participation
#    120. Track and Field Outdoor Men's Team Participation
#    121. Track and Field Outdoor Women's Team Participation
#    122. Track and Field Outdoor Total Participation
#    123. Track and Field X Country Men's Team Participation
#    124. Track and Field X Country Women's Team Participation
#    125. Track and Field X Country Total Participation
#    126. Volleyball Men's Team Participation
#    127. Volleyball Women's Team Participation
#    128. Volleyball Coed Team Men Participation
#    129. Volleyball Coed Team Women Participation
#    130. Volleyball Total Participation
#    131. Water Polo Men's Team Participation
#    132. Water Polo Women's Team Participation
#    133. Water Polo Total Participation
#    134. Weight Lifting Men's Team Participation
#    135. Weight Lifting Women's Team Participation
#    136. Weight Lifting Coed Team Men Participation
#    137. Weight Lifting Coed Team Women Participation
#    138. Weight Lifting Total Participation
#    139. Wrestling Men's Team Participation
#    140. Wrestling Women's Team Participation
#    141. Wrestling Coed Team Men Participation
#    142. Wrestling Coed Team Women Participation
#    143. Wrestling Total Participation
#    144. Other Sports Men's Team Participation
#    145. Other Sports Women's Team Participation
#    146. Other Sports Coed Team Men Participation
#    147. Other Sports Coed Team Women Participation
#    148. Other Sports Total Participation
#    149. Total Men's Team Participation
#    150. Total Women's Team Participation
#    151. Total Coed Team Men Participation
#    152. Total Coed Team Women Participation
#    153. Grand Total Men's Participation
#    154. Grand Total Women's Participation
#    155. Unduplicated Count Men's Participation
#    156. Unduplicated Count Women's Participation
#    157. Men's Team Average Annual Institutional Salary per Head Coach
#    158. Men's Team Number of Head Coaches Included in Average
#    159. Men's Team Average Annual Institutional Salary per FTE
#    160. Men's Team Number of FTEs Included in Average
#    161. Women's Team Average Annual Institutional Salary per Head Coach
#    162. Women's Team Number of Head Coaches Included in Average
#    163. Women's Team Average Annual Institutional Salary per FTE
#    164. Women's Team Number of FTEs Included in Average
#    165. Coed Team Average Annual Institutional Salary per Head Coach
#    166. Coed Team Number of Head Coaches Included in Average
#    167. Coed Team Average Annual Institutional Salary per FTE
#    168. Coed Team Number of FTEs Included in Average
#    169. Men's Team Average Annual Institutional Salary per Assistant Coach
#    170. Men's Team Number of Assistant Coaches Included in Average
#    171. Men's Team Average Annual Institutional Salary per FTE2
#    172. Men's Team Number of FTEs Included in Average2
#    173. Women's Team Average Annual Institutional Salary per Assistant Coach
#    174. Women's Team Number of Assistant Coaches Included in Average
#    175. Women's Team Average Annual Institutional Salary per FTE2
#    176. Women's Team Number of FTEs Included in Average2
#    177. Coed Team Average Annual Institutional Salary per Assistant Coach
#    178. Coed Team Number of Assistant Coaches Included in Average
#    179. Coed Team Average Annual Institutional Salary per FTE2
#    180. Coed Team Number of FTEs Included in Average2
#    181. Men's Team Athletic Student Aid
#    182. Women's Team Athletic Student Aid
#    183. Coed Team Athletic Student Aid
#    184. Archery Men's Team Revenue
#    185. Archery Women's Team Revenue
#    186. Archery Coed Team Revenue
#    187. Archery Total Revenue
#    188. Badminton Women's Team Revenue
#    189. Badminton Total Revenue
#    190. Baseball Men's Team Revenue
#    191. Baseball Total Revenue
#    192. Basketball Men's Team Revenue
#    193. Basketball Women's Team Revenue
#    194. Basketball Coed Team Revenue
#    195. Basketball Total Revenue
#    196. Beach Volleyball Men's Team Revenue
#    197. Beach Volleyball Women's Team Revenue
#    198. Beach Volleyball Total Revenue
#    199. Bowling Men's Team Revenue
#    200. Bowling Women's Team Revenue
#    201. Bowling Coed Team Revenue
#    202. Bowling Total Revenue
#    203. All Track Combined Men's Team Revenue
#    204. All Track Combined Women's Team Revenue
#    205. All Track Combined Coed Team Revenue
#    206. All Track Combined Total Revenue
#    207. Diving Men's Team Revenue
#    208. Diving Women's Team Revenue
#    209. Diving Total Revenue
#    210. Equestrian Men's Team Revenue
#    211. Equestrian Women's Team Revenue
#    212. Equestrian Coed Team Revenue
#    213. Equestrian Total Revenue
#    214. Fencing Men's Team Revenue
#    215. Fencing Women's Team Revenue
#    216. Fencing Coed Team Revenue
#    217. Fencing Total Revenue
#    218. Field Hockey Women's Team Revenue
#    219. Field Hockey Total Revenue
#    220. Football Men's Team Revenue
#    221. Football Total Revenue
#    222. Golf Men's Team Revenue
#    223. Golf Women's Team Revenue
#    224. Golf Coed Team Revenue
#    225. Golf Total Revenue
#    226. Gymnastics Men's Team Revenue
#    227. Gymnastics Women's Team Revenue
#    228. Gymnastics Coed Team Revenue
#    229. Gymnastics Total Revenue
#    230. Ice Hockey Men's Team Revenue
#    231. Ice Hockey Women's Team Revenue
#    232. Ice Hockey Total Revenue
#    233. Lacrosse Men's Team Revenue
#    234. Lacrosse Women's Team Revenue
#    235. Lacrosse Total Revenue
#    236. Rifle Men's Team Revenue
#    237. Rifle Women's Team Revenue
#    238. Rifle Coed Team Revenue
#    239. Rifle Total Revenue
#    240. Rodeo Men's Team Revenue
#    241. Rodeo Women's Team Revenue
#    242. Rodeo Coed Team Revenue
#    243. Rodeo Total Revenue
#    244. Rowing Men's Team Revenue
#    245. Rowing Women's Team Revenue
#    246. Rowing Total Revenue
#    247. Sailing Men's Team Revenue
#    248. Sailing Women's Team Revenue
#    249. Sailing Coed Team Revenue
#    250. Sailing Total Revenue
#    251. Skiing Men's Team Revenue
#    252. Skiing Women's Team Revenue
#    253. Skiing Total Revenue
#    254. Soccer Men's Team Revenue
#    255. Soccer Women's Team Revenue
#    256. Soccer Coed Team Revenue
#    257. Soccer Total Revenue
#    258. Softball Women's Team Revenue
#    259. Softball Total Revenue
#    260. Squash Men's Team Revenue
#    261. Squash Women's Team Revenue
#    262. Squash Coed Team Revenue
#    263. Squash Total Revenue
#    264. Swimming and Diving Men's Team Revenue
#    265. Swimming and Diving Women's Team Revenue
#    266. Swimming and Diving Total Revenue
#    267. Swimming Men's Team Revenue
#    268. Swimming Women's Team Revenue
#    269. Swimming Total Revenue
#    270. Synchronized Swimming Women's Team Revenue
#    271. Synchronized Swimming Total Revenue
#    272. Table Tennis Men's Team Revenue
#    273. Table Tennis Women's Team Revenue
#    274. Table Tennis Total Revenue
#    275. Tennis Men's Team Revenue
#    276. Tennis Women's Team Revenue
#    277. Tennis Coed Team Revenue
#    278. Tennis Total Revenue
#    279. Track and Field Indoor Men's Team Revenue
#    280. Track and Field Indoor Women's Team Revenue
#    281. Track and Field Indoor Total Revenue
#    282. Track and Field Outdoor Men's Team Revenue
#    283. Track and Field Outdoor Women's Team Revenue
#    284. Track and Field Outdoor Total Revenue
#    285. Track and Field X Country Men's Team Revenue
#    286. Track and Field X Country Women's Team Revenue
#    287. Track and Field X Country Total Revenue
#    288. Volleyball Men's Team Revenue
#    289. Volleyball Women's Team Revenue
#    290. Volleyball Coed Team Revenue
#    291. Volleyball Total Revenue
#    292. Water Polo Men's Team Revenue
#    293. Water Polo Women's Team Revenue
#    294. Water Polo Total Revenue
#    295. Weight Lifting Men's Team Revenue
#    296. Weight Lifting Women's Team Revenue
#    297. Weight Lifting Coed Team Revenue
#    298. Weight Lifting Total Revenue
#    299. Wrestling Men's Team Revenue
#    300. Wrestling Women's Team Revenue
#    301. Wrestling Coed Team Revenue
#    302. Wrestling Total Revenue
#    303. Other Sports Men's Team Revenue
#    304. Other Sports Women's Team Revenue
#    305. Other Sports Coed Team Revenue
#    306. Other Sports Total Revenue
#    307. Total Men's Team Revenue
#    308. Total Women's Team Revenue
#    309. Total Coed Team Revenue
#    310. Not Allocated by Sex/Sport Revenue
#    311. Grand Total Revenue
#    312. Men's Team Recruiting Expenses
#    313. Women's Team Recruiting Expenses
#    314. Coed Team Recruiting Expenses
#    315. Archery Men's Team Operating Expenses
#    316. Archery Women's Team Operating Expenses
#    317. Archery Coed Team Operating Expenses
#    318. Archery Total Operating Expenses
#    319. Badminton Men's Team Operating Expenses
#    320. Badminton Women's Team Operating Expenses
#    321. Badminton Total Operating Expenses
#    322. Baseball Men's Team Operating Expenses
#    323. Baseball Women's Team Operating Expenses
#    324. Baseball Total Operating Expenses
#    325. Basketball Men's Team Operating Expenses
#    326. Basketball Women's Team Operating Expenses
#    327. Basketball Coed Team Operating Expenses
#    328. Basketball Total Operating Expenses
#    329. Beach Volleyball Men's Team Operating Expenses
#    330. Beach Volleyball Women's Team Operating Expenses
#    331. Beach Volleyball Total Operating Expenses
#    332. Bowling Men's Team Operating Expenses
#    333. Bowling Women's Team Operating Expenses
#    334. Bowling Coed Team Operating Expenses
#    335. Bowling Total Operating Expenses
#    336. All Track Combined Men's Team Operating Expenses
#    337. All Track Combined Women's Team Operating Expenses
#    338. All Track Combined Coed Team Operating Expenses
#    339. All Track Combined Total Operating Expenses
#    340. Diving Men's Team Operating Expenses
#    341. Diving Women's Team Operating Expenses
#    342. Diving Total Operating Expenses
#    343. Equestrian Men's Team Operating Expenses
#    344. Equestrian Women's Team Operating Expenses
#    345. Equestrian Coed Team Operating Expenses
#    346. Equestrian Total Operating Expenses
#    347. Fencing Men's Team Operating Expenses
#    348. Fencing Women's Team Operating Expenses
#    349. Fencing Coed Team Operating Expenses
#    350. Fencing Total Operating Expenses
#    351. Field Hockey Men's Team Operating Expenses
#    352. Field Hockey Women's Team Operating Expenses
#    353. Field Hockey Total Operating Expenses
#    354. Football Men's Team Operating Expenses
#    355. Football Women's Team Operating Expenses
#    356. Football Total Operating Expenses
#    357. Golf Men's Team Operating Expenses
#    358. Golf Women's Team Operating Expenses
#    359. Golf Coed Team Operating Expenses
#    360. Golf Total Operating Expenses
#    361. Gymnastics Men's Team Operating Expenses
#    362. Gymnastics Women's Team Operating Expenses
#    363. Gymnastics Coed Team Operating Expenses
#    364. Gymnastics Total Operating Expenses
#    365. Ice Hockey Men's Team Operating Expenses
#    366. Ice Hockey Women's Team Operating Expenses
#    367. Ice Hockey Total Operating Expenses
#    368. Lacrosse Men's Team Operating Expenses
#    369. Lacrosse Women's Team Operating Expenses
#    370. Lacrosse Total Operating Expenses
#    371. Rifle Men's Team Operating Expenses
#    372. Rifle Women's Team Operating Expenses
#    373. Rifle Coed Team Operating Expenses
#    374. Rifle Total Operating Expenses
#    375. Rodeo Men's Team Operating Expenses
#    376. Rodeo Women's Team Operating Expenses
#    377. Rodeo Coed Team Operating Expenses
#    378. Rodeo Total Operating Expenses
#    379. Rowing Men's Team Operating Expenses
#    380. Rowing Women's Team Operating Expenses
#    381. Rowing Total Operating Expenses
#    382. Sailing Men's Team Operating Expenses
#    383. Sailing Women's Team Operating Expenses
#    384. Sailing Coed Team Operating Expenses
#    385. Sailing Total Operating Expenses
#    386. Skiing Men's Team Operating Expenses
#    387. Skiing Women's Team Operating Expenses
#    388. Skiing Total Operating Expenses
#    389. Soccer Men's Team Operating Expenses
#    390. Soccer Women's Team Operating Expenses
#    391. Soccer Coed Team Operating Expenses
#    392. Soccer Total Operating Expenses
#    393. Softball Men's Team Operating Expenses
#    394. Softball Women's Team Operating Expenses
#    395. Softball Total Operating Expenses
#    396. Squash Men's Team Operating Expenses
#    397. Squash Women's Team Operating Expenses
#    398. Squash Coed Team Operating Expenses
#    399. Squash Total Operating Expenses
#    400. Swimming and Diving Men's Team Operating Expenses
#    401. Swimming and Diving Women's Team Operating Expenses
#    402. Swimming and Diving Total Operating Expenses
#    403. Swimming Men's Team Operating Expenses
#    404. Swimming Women's Team Operating Expenses
#    405. Swimming Total Operating Expenses
#    406. Synchronized Swimming Men's Team Operating Expenses
#    407. Synchronized Swimming Women's Team Operating Expenses
#    408. Synchronized Swimming Total Operating Expenses
#    409. Table Tennis Men's Team Operating Expenses
#    410. Table Tennis Women's Team Operating Expenses
#    411. Table Tennis Total Operating Expenses
#    412. Tennis Men's Team Operating Expenses
#    413. Tennis Women's Team Operating Expenses
#    414. Tennis Coed Team Operating Expenses
#    415. Tennis Total Operating Expenses
#    416. Track and Field Indoor Men's Team Operating Expenses
#    417. Track and Field Indoor Women's Team Operating Expenses
#    418. Track and Field Indoor Total Operating Expenses
#    419. Track and Field Outdoor Men's Team Operating Expenses
#    420. Track and Field Outdoor Women's Team Operating Expenses
#    421. Track and Field Outdoor Total Operating Expenses
#    422. Track and Field X Country Men's Team Operating Expenses
#    423. Track and Field X Country Women's Team Operating Expenses
#    424. Track and Field X Country Total Operating Expenses
#    425. Volleyball Men's Team Operating Expenses
#    426. Volleyball Women's Team Operating Expenses
#    427. Volleyball Coed Team Operating Expenses
#    428. Volleyball Total Operating Expenses
#    429. Water Polo Men's Team Operating Expenses
#    430. Water Polo Women's Team Operating Expenses
#    431. Water Polo Total Operating Expenses
#    432. Weight Lifting Men's Team Operating Expenses
#    433. Weight Lifting Women's Team Operating Expenses
#    434. Weight Lifting Coed Team Operating Expenses
#    435. Weight Lifting Total Operating Expenses
#    436. Wrestling Men's Team Operating Expenses
#    437. Wrestling Women's Team Operating Expenses
#    438. Wrestling Coed Team Operating Expenses
#    439. Wrestling Total Operating Expenses
#    440. Other Sports Men's Team Operating Expenses
#    441. Other Sports Women's Team Operating Expenses
#    442. Other Sports Coed Team Operating Expenses
#    443. Other Sports Total Operating Expenses
#    444. Total Men's Team Operating Expenses
#    445. Total Women's Team Operating Expenses
#    446. Total Coed Team Operating Expenses
#    447. Grand Total Operating Expenses
#    448. Archery Men's Team Expenses
#    449. Archery Women's Team Expenses
#    450. Archery Coed Team Expenses
#    451. Archery Total Expenses
#    452. Badminton Women's Team Expenses
#    453. Badminton Total Expenses
#    454. Baseball Men's Team Expenses
#    455. Baseball Total Expenses
#    456. Basketball Men's Team Expenses
#    457. Basketball Women's Team Expenses
#    458. Basketball Coed Team Expenses
#    459. Basketball Total Expenses
#    460. Beach Volleyball Men's Team Expenses
#    461. Beach Volleyball Women's Team Expenses
#    462. Beach Volleyball Total Expenses
#    463. Bowling Men's Team Expenses
#    464. Bowling Women's Team Expenses
#    465. Bowling Coed Team Expenses
#    466. Bowling Total Expenses
#    467. All Track Combined Men's Team Expenses
#    468. All Track Combined Women's Team Expenses
#    469. All Track Combined Coed Team Expenses
#    470. All Track Combined Total Expenses
#    471. Diving Men's Team Expenses
#    472. Diving Women's Team Expenses
#    473. Diving Total Expenses
#    474. Equestrian Men's Team Expenses
#    475. Equestrian Women's Team Expenses
#    476. Equestrian Coed Team Expenses
#    477. Equestrian Total Expenses
#    478. Fencing Men's Team Expenses
#    479. Fencing Women's Team Expenses
#    480. Fencing Coed Team Expenses
#    481. Fencing Total Expenses
#    482. Field Hockey Women's Team Expenses
#    483. Field Hockey Total Expenses
#    484. Football Men's Team Expenses
#    485. Football Total Expenses
#    486. Golf Men's Team Expenses
#    487. Golf Women's Team Expenses
#    488. Golf Coed Team Expenses
#    489. Golf Total Expenses
#    490. Gymnastics Men's Team Expenses
#    491. Gymnastics Women's Team Expenses
#    492. Gymnastics Coed Team Expenses
#    493. Gymnastics Total Expenses
#    494. Ice Hockey Men's Team Expenses
#    495. Ice Hockey Women's Team Expenses
#    496. Ice Hockey Total Expenses
#    497. Lacrosse Men's Team Expenses
#    498. Lacrosse Women's Team Expenses
#    499. Lacrosse Total Expenses
#    500. Rifle Men's Team Expenses
#    501. Rifle Women's Team Expenses
#    502. Rifle Coed Team Expenses
#    503. Rifle Total Expenses
#    504. Rodeo Men's Team Expenses
#    505. Rodeo Women's Team Expenses
#    506. Rodeo Coed Team Expenses
#    507. Rodeo Total Expenses
#    508. Rowing Men's Team Expenses
#    509. Rowing Women's Team Expenses
#    510. Rowing Total Expenses
#    511. Sailing Men's Team Expenses
#    512. Sailing Women's Team Expenses
#    513. Sailing Coed Team Expenses
#    514. Sailing Total Expenses
#    515. Skiing Men's Team Expenses
#    516. Skiing Women's Team Expenses
#    517. Skiing Total Expenses
#    518. Soccer Men's Team Expenses
#    519. Soccer Women's Team Expenses
#    520. Soccer Coed Team Expenses
#    521. Soccer Total Expenses
#    522. Softball Women's Team Expenses
#    523. Softball Total Expenses
#    524. Squash Men's Team Expenses
#    525. Squash Women's Team Expenses
#    526. Squash Coed Team Expenses
#    527. Squash Total Expenses
#    528. Swimming and Diving Men's Team Expenses
#    529. Swimming and Diving Women's Team Expenses
#    530. Swimming and Diving Total Expenses
#    531. Swimming Men's Team Expenses
#    532. Swimming Women's Team Expenses
#    533. Swimming Total Expenses
#    534. Synchronized Swimming Women's Team Expenses
#    535. Synchronized Swimming Total Expenses
#    536. Table Tennis Men's Team Expenses
#    537. Table Tennis Women's Team Expenses
#    538. Table Tennis Total Expenses
#    539. Tennis Men's Team Expenses
#    540. Tennis Women's Team Expenses
#    541. Tennis Coed Team Expenses
#    542. Tennis Total Expenses
#    543. Track and Field Indoor Men's Team Expenses
#    544. Track and Field Indoor Women's Team Expenses
#    545. Track and Field Indoor Total Expenses
#    546. Track and Field Outdoor Men's Team Expenses
#    547. Track and Field Outdoor Women's Team Expenses
#    548. Track and Field Outdoor Total Expenses
#    549. Track and Field X Country Men's Team Expenses
#    550. Track and Field X Country Women's Team Expenses
#    551. Track and Field X Country Total Expenses
#    552. Volleyball Men's Team Expenses
#    553. Volleyball Women's Team Expenses
#    554. Volleyball Coed Team Expenses
#    555. Volleyball Total Expenses
#    556. Water Polo Men's Team Expenses
#    557. Water Polo Women's Team Expenses
#    558. Water Polo Total Expenses
#    559. Weight Lifting Men's Team Expenses
#    560. Weight Lifting Women's Team Expenses
#    561. Weight Lifting Coed Team Expenses
#    562. Weight Lifting Total Expenses
#    563. Wrestling Men's Team Expenses
#    564. Wrestling Women's Team Expenses
#    565. Wrestling Coed Team Expenses
#    566. Wrestling Total Expenses
#    567. Other Sports Men's Team Expenses
#    568. Other Sports Women's Team Expenses
#    569. Other Sports Coed Team Expenses
#    570. Other Sports Total Expenses
#    571. Total Men's Team Expenses
#    572. Total Women's Team Expenses
#    573. Total Coed Team Expenses
#    574. Not Allocated by Sex/Sport Expenses
#    575. Grand Total Expenses
#    576. Division
#    577. Total_Athletes
#    578. Efficiency_Ratio
#    579. Revenue_Per_Athlete
#    580. Reports_Exactly_One
#    581. Revenue_Growth_1yr
#    582. Expense_Growth_1yr
#    583. Revenue_CAGR_2yr
#    584. Expense_CAGR_2yr
#    585. Efficiency_Mean_2yr
#    586. Revenue_Volatility_2yr
#    587. Expense_Volatility_2yr
#
# Total features: 587

# %%
# ============================================
# LEAKAGE CHECK 3: No Future-Looking Features
# ============================================

print("\n🔍 LEAKAGE CHECK 3: Checking for future-looking features...")
print("="*60)

# Check for any column containing 'Future'
future_cols = [col for col in all_columns if 'Future' in col]

if len(future_cols) == 0:
    print("✅ PASS: No future-looking features found")
else:
    print("❌ FAIL: Found future-looking features:")
    for col in future_cols:
        print(f"   - {col}")

# Check for any 'Lag1_Target' or similar
lag_target_cols = [col for col in all_columns if 'Lag' in col and 'Target' in col]

if len(lag_target_cols) == 0:
    print("✅ PASS: No lagged target features found")
else:
    print("❌ FAIL: Found lagged target features:")
    for col in lag_target_cols:
        print(f"   - {col}")
# Out:
# 🔍 LEAKAGE CHECK 3: Checking for future-looking features...
# ============================================================
# ✅ PASS: No future-looking features found
# ✅ PASS: No lagged target features found

# %%
# ============================================
# LEAKAGE CHECK SUMMARY
# ============================================

print("\n" + "="*60)
print("📋 LEAKAGE CHECK SUMMARY")
print("="*60)

checks_passed = (
    len(forbidden_target_cols) == 0 and
    len(future_cols) == 0 and
    len(lag_target_cols) == 0
)

if checks_passed:
    print("\n✅ ALL CHECKS PASSED - Dataset is leak-free!")
    print("\nSafe to proceed with temporal split and model training.")
else:
    print("\n❌ CHECKS FAILED - Dataset has potential leakage!")
    print("\nDO NOT proceed until issues are fixed.")
# Out:
# ============================================================
# 📋 LEAKAGE CHECK SUMMARY
# ============================================================
#
# ✅ ALL CHECKS PASSED - Dataset is leak-free!
#
# Safe to proceed with temporal split and model training.

# %% [markdown]
# ---
# ## 11. Select Final Columns and Save

# %%
# ============================================
# SELECT FINAL COLUMNS
# ============================================

# Columns to keep in final dataset
final_columns = [
    # Identifiers (kept for reference, not used in model)
    'UNITID', 'Institution_Name', 'Year', 'State',
    
    # Structural features
    'Division',
    
    # Current metrics
    'Grand Total Revenue', 'Grand Total Expenses', 'Total_Athletes',
    'Efficiency_Ratio', 'Revenue_Per_Athlete', 'Reports_Exactly_One',
    
    # Growth features (1-year)
    'Revenue_Growth_1yr', 'Expense_Growth_1yr',
    
    # Trend features (2-year)
    'Revenue_CAGR_2yr', 'Expense_CAGR_2yr', 'Efficiency_Mean_2yr',
    
    # Volatility features
    'Revenue_Volatility_2yr', 'Expense_Volatility_2yr',
    
    # Target (only for training data)
    'Target_Trajectory', 'Target_Label'
]

# Filter to only existing columns
final_columns = [col for col in final_columns if col in df_train.columns]

df_train_final = df_train[final_columns].copy()

# For prediction data, exclude target columns
pred_columns = [col for col in final_columns if col not in ['Target_Trajectory', 'Target_Label']]
df_predict_final = df_predict[pred_columns].copy()

print(f"✅ Final training dataset: {df_train_final.shape}")
print(f"✅ Final prediction dataset: {df_predict_final.shape}")
# Out:
# ✅ Final training dataset: (12054, 20)
# ✅ Final prediction dataset: (1722, 18)

# %%
# ============================================
# SAVE DATASETS
# ============================================

# Save training data (2017-2022 with targets)
train_path = '../data/processed/features_temporal.csv'
df_train_final.to_csv(train_path, index=False)
print(f"✅ Saved training data to: {train_path}")

# Save prediction data (2023 without targets)
predict_path = '../data/processed/features_2023_predict.csv'
df_predict_final.to_csv(predict_path, index=False)
print(f"✅ Saved prediction data to: {predict_path}")
# Out:
# ✅ Saved training data to: ../data/processed/features_temporal.csv
# ✅ Saved prediction data to: ../data/processed/features_2023_predict.csv

# %% [markdown]
# ---
# ## 12. Final Summary

# %%
# ============================================
# FEATURE ENGINEERING SUMMARY
# ============================================

summary = f"""
╔══════════════════════════════════════════════════════════════════════════════╗
║                     FEATURE ENGINEERING COMPLETE                             ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║  TRAINING DATA (features_temporal.csv):                                      ║
║  ─────────────────────────────────────────                                   ║
║  • Rows: {len(df_train_final):,}                                                         ║
║  • Years: {df_train_final['Year'].min()} - {df_train_final['Year'].max()}                                                        ║
║  • Institutions: {df_train_final['UNITID'].nunique():,}                                                    ║
║  • Features: {len(final_columns) - 6} (excluding identifiers and target)                            ║
║                                                                              ║
║  PREDICTION DATA (features_2023_predict.csv):                                ║
║  ─────────────────────────────────────────────                               ║
║  • Rows: {len(df_predict_final):,}                                                          ║
║  • Year: {df_predict_final['Year'].unique()[0] if len(df_predict_final) > 0 else 'N/A'}                                                             ║
║  • No target (true future prediction)                                        ║
║                                                                              ║
║  CLASS DISTRIBUTION (Training):                                              ║
║  ─────────────────────────────────                                           ║
║  • Declining: {(df_train_final['Target_Trajectory'] == 'Declining').sum():,} ({(df_train_final['Target_Trajectory'] == 'Declining').mean()*100:.1f}%)                                            ║
║  • Stable:    {(df_train_final['Target_Trajectory'] == 'Stable').sum():,} ({(df_train_final['Target_Trajectory'] == 'Stable').mean()*100:.1f}%)                                            ║
║  • Improving: {(df_train_final['Target_Trajectory'] == 'Improving').sum():,} ({(df_train_final['Target_Trajectory'] == 'Improving').mean()*100:.1f}%)                                            ║
║                                                                              ║
║  LEAKAGE STATUS: ✅ VERIFIED CLEAN                                           ║
║                                                                              ║
╚══════════════════════════════════════════════════════════════════════════════╝

NEXT STEP: Proceed to 05_Temporal_Split.ipynb
→ Split data by time: train (2017-2019), val (2020-2021), holdout (2022)
"""

print(summary)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║                     FEATURE ENGINEERING COMPLETE                             ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║  TRAINING DATA (features_temporal.csv):                                      ║
# ║  ─────────────────────────────────────────                                   ║
# ║  • Rows: 12,054                                                         ║
# ║  • Years: 2016 - 2022                                                        ║
# ║  • Institutions: 1,722                                                    ║
# ║  • Features: 14 (excluding identifiers and target)                            ║
# ║                                                                              ║
# ║  PREDICTION DATA (features_2023_predict.csv):                                ║
# ║  ─────────────────────────────────────────────                               ║
# ║  • Rows: 1,722                                                          ║
# ║  • Year: 2023                                                             ║
# ║  • No target (true future prediction)                                        ║
# ║                                                                              ║
# ║  CLASS DISTRIBUTION (Training):                                              ║
# ║  ─────────────────────────────────                                           ║
# ║  • Declining: 4,719 (39.1%)                                            ║
# ║  • Stable:    5,694 (47.2%)                                            ║
# ║  • Improving: 1,641 (13.6%)                                            ║
# ║                                                                              ║
# ║  LEAKAGE STATUS: ✅ VERIFIED CLEAN                                           ║
# ║                                                                              ║
# ╚══════════════════════════════════════════════════════════════════════════════╝
#
# NEXT STEP: Proceed to 05_Temporal_Split.ipynb
# → Split data by time: train (2017-2019), val (2020-2021), holdout (2022)

# %% [markdown]
# ---
# ## ✅ Checkpoint Complete
#
# We've built:
# 1. **15 features** across 6 categories (all leak-free)
# 2. **Target variable** with 3 classes
# 3. **Training dataset**: 2017-2022 (~10,332 rows)
# 4. **Prediction dataset**: 2023 (~1,722 rows)
#
# **Leakage verification passed** — no target-derived or future-looking features.
#
# **Next Notebook:** `05_Temporal_Split.ipynb`
# We'll split the training data by time to ensure proper temporal validation.
